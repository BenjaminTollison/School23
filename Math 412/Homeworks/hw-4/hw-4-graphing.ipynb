# %%
### Benjamin Tollison ###
import sympy as sp
from IPython.display import display, Math, Latex
from sympy.solvers.solveset import linsolve
from sympy import  lambdify, Matrix,sin,cos, sinh, cosh, exp, pi, symbols, integrate
import numpy as np
import matplotlib.pyplot as plt
def displayEquations(LHS,RHS):
    left = sp.latex(LHS)
    right = sp.latex(RHS)
    display(Math(left + '=' + right))
    np.set_printoptions(suppress=True)

# %%
t = []
import matplotlib.colors as mcolors
names = list(mcolors)
for i in range(10):
    t.append(i)
u_x1 = [1] * 100
u_x2 = [0] * 100
for i in t:
    x_values = np.linspace(i, i+2, 100)
    plt.plot(x_values, u_x1, label='t = ' + str(i),color = j)
    plt.vlines(i,0,1,color = j)
    plt.vlines(i+2,0,1,color = j)
plt.legend()
plt.ylim(0,2)
plt.hlines(0,-10,0)
plt.show()
